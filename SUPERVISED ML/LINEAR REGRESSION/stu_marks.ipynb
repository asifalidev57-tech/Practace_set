# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student.csv')
df.head()
# Out:
#    Study_Hours  Marks
# 0            1     15
# 1            2     22
# 2            3     30
# 3            4     39
# 4            5     48

# %%
plt.scatter(df['Study_Hours'], df['Marks'])
plt.plot(df['Study_Hours'], df['Marks'])
x=df[['Study_Hours']]
y=df['Marks']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train, y_train)
print(regression.coef_)
print(regression.intercept_)
# Out:
# [23.25768864]
# 56.333333333333336

# %%
plt.scatter(x_train, y_train)
plt .plot(x_train, regression.predict(x_train))
y_pred=regression.predict(x_test)
print(y_pred)
# Out:
# [93.70810056 85.88547486 15.48184358]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae=mean_absolute_error(y_test, y_pred)
mse=mean_absolute_error(y_test, y_pred)
rmse=np.sqrt(mse)
print(mae)
print(mse)
print(rmse)
# Out:
# 0.9627560521415409
# 0.9627560521415409
# 0.9812013310944604

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test, y_pred)
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.9975244209471124

# %%
import statsmodels.api as sm
x_train = sm.add_constant(x_train)
model=sm.OLS(y_train, x_train).fit()
x_test=sm.add_constant(x_test)
prediction=model.predict(x_test)
print(prediction)
# Out:
# [93.70810056 85.88547486 15.48184358]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)
# Out:
# MAE : 0.9627560521415409
# MSE : 1.5961983604340402
# RMSE: 1.2634074403904862

# %%
print(y_pred)
print(prediction)

print(np.allclose(y_pred, prediction))
print(model.params)
# Out:
# [93.70810056 85.88547486 15.48184358]
# [93.70810056 85.88547486 15.48184358]
# True
# const    56.333333
# x1       23.257689
# dtype: float64

# %%
regression.predict(scaler.transform([[11]]))
# Out:
# c:\Users\DELL\Desktop\python practice set\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([93.70810056])
